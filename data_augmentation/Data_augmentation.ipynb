# %% [markdown]
# <a href="https://colab.research.google.com/github/learn-ai-python/Machine_Learning/blob/master/data_augmentation/Data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 DATA AUGMENTATION (АУГМЕНТАЦІЯ ДАНИХ)
# 📸 Instagram: @learn.ai.python

# %% [markdown]
# ### 📚 Імпорт бібліотек

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 🖼️ Зчитування зображення

# %%
image_path = 'cat.jpg'
img = tf.keras.utils.load_img(image_path)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
plt.figure(figsize=(4, 4))
plt.imshow(img)
# plt.axis('off')
plt.show()

# %% [markdown]
# ### 🐬 Вибір аугментації даних

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomFlip("vertical"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.9),
    tf.keras.layers.RandomTranslation(0.01, 0.05),
    tf.keras.layers.RandomContrast(0.3),
])

# %% [markdown]
# ### 📊 Виведення результатів

# %%
plt.figure(figsize=(20, 20))
plt.subplots_adjust(wspace=0, hspace=0)

for i in range(9):
  augmented_image = data_augmentation(img_array)
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0].numpy().astype('uint8'))
  # plt.axis("off")
